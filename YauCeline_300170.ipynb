# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helpers.helper_functions import *

# %% [markdown]
# # The Significant Bang Theory
#
# Attention, ADA students!
#
# The Sheldon Cooper we all know and love (OK, some of us might not know him, and some might not love him) from the TV series "The Big Bang Theory" has gotten into an argument with Leonard from the same TV show. Sheldon insists that he knows the show better than anyone, and keeps making various claims about the show, which neither of them know how to prove or disprove. The two of them have reached out to you ladies and gentlemen, as data scientists, to help them. You will be given the full script of the series, with information on the episode, the scene, the person saying each dialogue line, and the dialogue lines themselves.
#
# Leonard has challenged several of Sheldon's claims about the show, and throughout this exam you will see some of those and you will get to prove or disprove them, but remember: sometimes, we can neither prove a claim, nor disprove it!
#
# ## Deadline
# Wednesday, January 30th, 2019; 11:15 A.M. (Swiss time)
#
# _For the deadline for extramural exams, see the submission subsection._
#
# ## Important notes
# * Don't forget to add a textual description of your thought process, the assumptions you made, and your results!
# * Please write all your comments in English, and use meaningful variable names in your code.
# * As we have seen during the semester, data science is all about multiple iterations on the same dataset. Do not obsess over small details in the beginning, and try to complete as many tasks as possible during the first 2 hours. Then, go back to the obtained results, write meaningful comments, and debug your code if you have found any glaring mistake.
# * Fully read the instructions for each question before starting to solve it to avoid misunderstandings, and remember to save your notebook often!
# * The exam contains **15 questions organised into 4 tasks**, and is designed for more than 3 hours. **You do not need to solve everything in order to get a 6**, and you have some freedom is choosing the tasks you wish to solve.
# * You cannot leave the room in the first and last 15 minutes.
# * You can use all the online resources you want except for communication tools (emails, web chats, forums, phone, etc.). We will be monitoring the network for unusual activity.
# * Remember, this is not a homework assignment -- no teamwork allowed!
#
# ## Submission
# * Your file has to be named as "NameSurname_SCIPER.ipynb".
# * Make sure you upload your Jupyter Notebook (1 file) to [this](https://goo.gl/forms/7GLvYl94uSOn54jH2) Google form at the end of the exam, with all the cells already evaluated (except for the Spark-related question, Q7). You need to sign in to Google using your EPFL credentials in order to submit the form.
# * In case of problems with the form, send your Jupyter Notebook (along with your name and SCIPER number) as a direct message to @ramtin on Mattermost. This is reserved only for those who encounter problems with the submission -- you need to have a reasonable justification for using this back-up.
# * You will have until 11:20 (strict deadline) to turn in your submission. **Late submissions will not be accepted.** This deadline is for the students taking the exam at EPFL -- students taking the exam extramurally will have their submission deadline as the starting time of the exam plus 3 hours and 5 minutes.

# %% [markdown]
# ## Task A: Picking up the shovel (10 points)
#
# **Note: You will use the data you preprocess in this task in all the subsequent ones.**
#
# Our friends' argument concerns the entire show. We have given you a file in the `data/` folder that contains the script of every single episode. New episodes are indicated by '>>', new scenes by '>', and the rest of the lines are dialogue lines. Some lines are said by multiple people (for example, lines indicated by 'All' or 'Together'); **you must discard these lines**, for the sake of simplicity. However, you do not need to do it for Q1 in this task -- you'll take care of it when you solve Q2.
#
# **Q1**. (5 points) Your first task is to extract all lines of dialogue in each scene and episode, creating a dataframe where each row has the episode and scene where a dialogue line was said, the character who said it, and the line itself. You do not need to extract the proper name of the episode (e.g. episode 1 can appear as "Series 01 Episode 01 - Pilot Episode", and doesn't need to appear as "Pilot Episode"). Then, answer the following question: In total, how many scenes are there in each season? We're not asking about unique scenes; the same location appearing in two episodes counts as two scenes. You can use a Pandas dataframe with a season column and a scene count column as the response.
#
# **Note: The data refers to seasons as "series".**

# %%
data = './data/'
script_file = data+'all_scripts.txt'

# %%
f = open(script_file)
lines = [line.rstrip('\n') for line in f]

df_script = pd.DataFrame(columns=('episode', 'scene', 'character', 'line'))
episode = ''
scene = ''

dict_script = {}
def parse_line(line):
    script = line.split(':')
    return script[0], script[1]

for line in lines:
    if line.startswith('>>'):
        episode = line.replace('>>', '')
    elif line.startswith('>'):
        scene = line.replace('>', '')
    else:
        character, dialogue = parse_line(line)
        row = {
            'episode': episode,
            'scene': scene,
            'character': character,
            'line': dialogue
        }
        df_script = df_script.append(row, ignore_index=True)

df_script.head()
# Out:
#                                  episode                         scene  \
# 0   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 1   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 2   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 3   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 4   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
#
#       character                                               line
# 0       Sheldon   So if a photon is directed through a plane wi...
# 1       Leonard                         Agreed, what’s your point?
# 2       Sheldon   There’s no point, I just think it’s a good id...
# 3       Leonard                                         Excuse me?
# 4  Receptionist                                           Hang on.

# %% [markdown]
# **Q2**. (5 points) Now, let's define two sets of characters: all the characters, and recurrent characters. Recurrent characters are those who appear in more than one episode. For the subsequent sections, you will need to have a list of recurrent characters. Assume that there are no two _named characters_ (i.e. characters who have actual names and aren't referred to generically as "little girl", "grumpy grandpa", etc.) with the same name, i.e. there are no two Sheldons, etc. Generate a list of recurrent characters who have more than 90 dialogue lines in total, and then take a look at the list you have. If you've done this correctly, you should have a list of 20 names. However, one of these is clearly not a recurrent character. Manually remove that one, and print out your list of recurrent characters. To remove that character, pay attention to the _named character_ assumption we gave you earlier on. **For all the subsequent questions, you must only keep the dialogue lines said by the recurrent characters in your list.**
#
# _Hint: "I know all the recurrent characters because I've watched the entire series five times" is not an acceptable argument, so you need to actually generate the list._

# %%
df_char = df_script.copy()

# get recurrent characters
df_recc = df_char.groupby(['character'])['episode'].count().reset_index()
df_recc = df_recc[df_recc['episode'] > 1]
recc_name = df_recc['character'].values.tolist()

# more than 90 characters
df_char = df_char.groupby(['character'])['line'].count().reset_index()
df_char = df_char[df_char['line'] > 90]
df_char = df_char[df_char['character'].isin(recc_name)]

# drop man b/c it is not a recurrent character
df_char = df_char[df_char['character'] != 'Man']

df_char
# Out:
#         character   line
# 10            Amy   3472
# 13         Arthur    130
# 20     Bernadette   2690
# 21           Bert     95
# 23       Beverley    162
# 52          Emily    164
# 71         Howard   5872
# 90         Kripke    106
# 95        Leonard   9829
# 98         Leslie    116
# 121    Mrs Cooper    213
# 128  Mrs Wolowitz    136
# 137         Penny   7677
# 142         Priya    222
# 147           Raj   4779
# 160       Sheldon  11689
# 173        Stuart    733
# 191           Wil    126
# 196          Zack    135

# %%
# grabbing only the reccurent character's lines
df_diag = df_script.copy()
df_diag = df_diag[df_diag['character'].isin(df_char['character'].values.tolist())]

# %% [markdown]
# ## Task B: Read the ~~stats~~ scripts carefully (30 points)
#
# ### Part 1: Don't put the shovel down just yet
#
# **Q3**. (2.5 points) From each dialogue line, replace punctuation marks (listed in the EXCLUDE_CHARS variable provided in `helpers/helper_functions.py`) with whitespaces, and lowercase all the text. **Do not remove any stopwords, leave them be for all the questions in this task.**

# %%
df_diag['line'].replace(EXCLUDE_CHARS,'',inplace=True)
df_diag['line'] = df_diag['line'].str.lower()

df_diag.head()
# Out:
#                                  episode                         scene  \
# 0   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 1   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 2   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 3   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
# 5   Series 01 Episode 01 – Pilot Episode   A corridor at a sperm bank.
#
#   character                                               line
# 0   Sheldon   so if a photon is directed through a plane wi...
# 1   Leonard                         agreed, what’s your point?
# 2   Sheldon   there’s no point, i just think it’s a good id...
# 3   Leonard                                         excuse me?
# 5   Leonard   one across is aegean, eight down is nabakov, ...

# %% [markdown]
# **Q4**. (5 points) For each term, calculate its "corpus frequency", i.e. its number of occurrences in the entire series. Visualize the distribution of corpus frequency using a histogram. Explain your observations. What are the appropriate x and y scales for this plot?

# %%
corp_freq = df_diag['line'].str.split(expand=True).stack().value_counts().reset_index()

# %%
# rename columns
corp_freq.columns = ['word', 'count']

plt.hist(corp_freq['count'], bins=100, log=True)
# Out:
# (array([3.8075e+04, 1.4200e+02, 6.7000e+01, 2.6000e+01, 2.5000e+01,
#         1.3000e+01, 1.0000e+01, 1.0000e+01, 6.0000e+00, 3.0000e+00,
#         3.0000e+00, 5.0000e+00, 3.0000e+00, 1.0000e+00, 2.0000e+00,
#         2.0000e+00, 3.0000e+00, 2.0000e+00, 3.0000e+00, 3.0000e+00,
#         4.0000e+00, 3.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([1.000000e+00, 1.752700e+02, 3.495400e+02, 5.238100e+02,
#         6.980800e+02, 8.723500e+02, 1.046620e+03, 1.220890e+03,
#         1.395160e+03, 1.569430e+03, 1.743700e+03, 1.917970e+03,
#         2.092240e+03, 2.266510e+03, 2.440780e+03, 2.615050e+03,
#         2.789320e+03, 2.963590e+03, 3.137860e+03, 3.312130e+03,
#         3.486400e+03, 3.660670e+03, 3.834940e+03, 4.009210e+03,
#         4.183480e+03, 4.357750e+03, 4.532020e+03, 4.706290e+03,
#         4.880560e+03, 5.054830e+03, 5.229100e+03, 5.403370e+03,
#         5.577640e+03, 5.751910e+03, 5.926180e+03, 6.100450e+03,
#         6.274720e+03, 6.448990e+03, 6.623260e+03, 6.797530e+03,
#         6.971800e+03, 7.146070e+03, 7.320340e+03, 7.494610e+03,
#         7.668880e+03, 7.843150e+03, 8.017420e+03, 8.191690e+03,
#         8.365960e+03, 8.540230e+03, 8.714500e+03, 8.888770e+03,
#         9.063040e+03, 9.237310e+03, 9.411580e+03, 9.585850e+03,
#         9.760120e+03, 9.934390e+03, 1.010866e+04, 1.028293e+04,
#         1.045720e+04, 1.063147e+04, 1.080574e+04, 1.098001e+04,
#         1.115428e+04, 1.132855e+04, 1.150282e+04, 1.167709e+04,
#         1.185136e+04, 1.202563e+04, 1.219990e+04, 1.237417e+04,
#         1.254844e+04, 1.272271e+04, 1.289698e+04, 1.307125e+04,
#         1.324552e+04, 1.341979e+04, 1.359406e+04, 1.376833e+04,
#         1.394260e+04, 1.411687e+04, 1.429114e+04, 1.446541e+04,
#         1.463968e+04, 1.481395e+04, 1.498822e+04, 1.516249e+04,
#         1.533676e+04, 1.551103e+04, 1.568530e+04, 1.585957e+04,
#         1.603384e+04, 1.620811e+04, 1.638238e+04, 1.655665e+04,
#         1.673092e+04, 1.690519e+04, 1.707946e+04, 1.725373e+04,
#         1.742800e+04]),
#  <a list of 100 Patch objects>)

# %% [markdown]
# The appropriate scale for this graph is y = logarithmic and x = normal. From this we can see that a small number of words are used very frequently. While a large number of other words are used a small number of times.

# %% [markdown]
# ### Part 2: Talkativity
# **Q5**. (2.5 points) For each of the recurrent characters, calculate their total number of words uttered across all episodes. Based on this, who seems to be the most talkative character?

# %%
df_total = df_diag.copy()

# join everyline the character speaks into one box
df_total = df_total.groupby('character')['line'].apply(lambda x: ' '.join(x)).reset_index()

df_total['num_words'] = df_total['line'].str.split().str.len()

df_total.sort_values('num_words', ascending=False, inplace=True)
df_total.head()
# Out:
#    character                                               line  num_words
# 15   Sheldon   so if a photon is directed through a plane wi...     174160
# 8    Leonard   agreed, what’s your point?  excuse me?  one a...      95414
# 12     Penny   oh, hi!  hi?  oh, that’s nice.  oh, okay, wel...      74176
# 6     Howard   wait till you see this.  it’s a stephen hawki...      64953
# 14       Raj   it’s fantastic. unbelievable.  why?  smooth. ...      56313

# %% [markdown]
# Based on the chart above, Sheldon would be the most talkative character.

# %% [markdown]
# **Q6**. (12.5 points) For each of the recurrent characters, calculate their total number of words uttered per episode (ignoring episodes that the character does not appear in), and calculate a **robust summary statistic** for the word count distribution of each person.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**i)** (2.5 points) What changes do you observe, compared to the analysis in Q5?
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**ii)** (2.5 points) Why is this analysis an improvement over the previous one, and how could you improve it even further? _Hint: The improvement involves making your unit for word counts even more granular - you can go further down than episodes._
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**iii)** (7.5 points) Incorporate that improvement. Do you still see the same results? How **confident** can you be that the "most talkative" person given by this twice improved method is really more talkative than the second most talkative one? _Hint: Read the question again. A good idea would be to use bootstrapping and calculate your summary statistic on each bootstrapped set._

# %%
df_ep = df_diag.copy()

# join the lines spoken by each character in each episode
df_ep = df_ep.groupby(['character', 'episode'])['line'].apply(lambda x: ' '.join(x)).reset_index()

df_ep['num_words'] = df_ep['line'].str.split().str.len()

list_characters = df_total['character'].unique()

for character in list_characters:
    df_ep_ch = df_ep[df_ep['character'] == character]
    print('CHARACTER: {}'.format(character))
    print(df_ep_ch.describe())
# Out:
# CHARACTER: Sheldon
#          num_words
# count   231.000000
# mean    753.939394
# std     238.264022
# min     233.000000
# 25%     593.000000
# 50%     729.000000
# 75%     886.000000
# max    1529.000000
# CHARACTER: Leonard
#          num_words
# count   231.000000
# mean    413.047619
# std     197.345322
# min      86.000000
# 25%     272.500000
# 50%     370.000000
# 75%     543.500000
# max    1343.000000
# CHARACTER: Penny
#         num_words
# count  229.000000
# mean   323.912664
# std    144.459735
# min     82.000000
# 25%    214.000000
# 50%    303.000000
# 75%    394.000000
# max    834.000000
# CHARACTER: Howard
#         num_words
# count  231.000000
# mean   281.181818
# std    147.213249
# min     30.000000
# 25%    172.000000
# 50%    269.000000
# 75%    361.500000
# max    706.000000
# CHARACTER: Raj
#         num_words
# count  230.000000
# mean   244.839130
# std    170.292133
# min      1.000000
# 25%    112.500000
# 50%    207.000000
# 75%    328.500000
# max    919.000000
# CHARACTER: Amy
#         num_words
# count  154.000000
# mean   242.389610
# std    133.505884
# min     19.000000
# 25%    164.500000
# 50%    218.000000
# 75%    297.750000
# max    879.000000
# CHARACTER: Bernadette
#         num_words
# count  161.000000
# mean   160.229814
# std     89.531227
# min     13.000000
# 25%     96.000000
# 50%    145.000000
# 75%    214.000000
# max    527.000000
# CHARACTER: Stuart
#         num_words
# count   60.000000
# mean   123.416667
# std     75.629178
# min      6.000000
# 25%     70.750000
# 50%    105.000000
# 75%    169.000000
# max    437.000000
# CHARACTER: Mrs Cooper
#         num_words
# count     8.00000
# mean    400.62500
# std     384.62484
# min      33.00000
# 25%     146.25000
# 50%     278.00000
# 75%     546.50000
# max    1183.00000
# CHARACTER: Beverley
#        num_words
# count    5.00000
# mean   383.60000
# std    346.84622
# min     62.00000
# 25%    169.00000
# 50%    176.00000
# 75%    678.00000
# max    833.00000
# CHARACTER: Priya
#         num_words
# count   12.000000
# mean   152.000000
# std     70.102522
# min     63.000000
# 25%     97.750000
# 50%    133.000000
# 75%    194.500000
# max    269.000000
# CHARACTER: Wil
#         num_words
# count   12.000000
# mean   131.416667
# std    104.252716
# min     29.000000
# 25%     53.000000
# 50%    116.500000
# 75%    165.750000
# max    405.000000
# CHARACTER: Emily
#         num_words
# count   17.000000
# mean    86.588235
# std     49.857370
# min     20.000000
# 25%     37.000000
# 50%     81.000000
# 75%    129.000000
# max    163.000000
# CHARACTER: Mrs Wolowitz
#         num_words
# count   27.000000
# mean    50.518519
# std     45.330725
# min      6.000000
# 25%     22.000000
# 50%     38.000000
# 75%     63.500000
# max    191.000000
# CHARACTER: Arthur
#         num_words
# count    4.000000
# mean   338.250000
# std    107.008956
# min    254.000000
# 25%    272.750000
# 50%    303.500000
# 75%    369.000000
# max    492.000000
# CHARACTER: Zack
#         num_words
# count    8.000000
# mean   167.000000
# std    128.647914
# min     17.000000
# 25%     98.250000
# 50%    128.500000
# 75%    221.750000
# max    422.000000
# CHARACTER: Leslie
#         num_words
# count    7.000000
# mean   166.285714
# std    165.235906
# min     27.000000
# 25%     63.500000
# 50%    112.000000
# 75%    195.000000
# max    508.000000
# CHARACTER: Kripke
#        num_words
# count    8.00000
# mean   145.37500
# std     90.56164
# min     21.00000
# 25%     83.00000
# 50%    145.00000
# 75%    214.75000
# max    265.00000
# CHARACTER: Bert
#         num_words
# count    6.000000
# mean   177.500000
# std     52.985847
# min     98.000000
# 25%    151.500000
# 50%    182.500000
# 75%    203.000000
# max    251.000000

# %% [markdown]
# The robust summary statistics are the min, 25%, 50%, 75% and max. From those values, I notice that Raj has a few episodes where he does not say much (approx 1 or 2 words) but, his max word count is higher than Howard's. The same trend occurs for somme of the lower total worded characters. For example Mrs. Cooper has a max word count of 1183 which is higher than Penny, who is much higher on the list from Q5.

# %%
df_scene = df_diag.copy()

# join the lines spoken by each character in each scene
df_scene = df_scene.groupby(['character', 'scene'])['line'].apply(lambda x: ' '.join(x)).reset_index()

df_scene['num_words'] = df_scene['line'].str.split().str.len()

list_characters = df_total['character'].unique()

for character in list_characters:
    df_sc_ch = df_scene[df_scene['character'] == character]
    print('CHARACTER: {}'.format(character))
    print(df_sc_ch.describe())
# Out:
# CHARACTER: Sheldon
#           num_words
# count    603.000000
# mean     288.822554
# std     2045.960126
# min        1.000000
# 25%       51.000000
# 50%      113.000000
# 75%      193.000000
# max    48941.000000
# CHARACTER: Leonard
#           num_words
# count    534.000000
# mean     178.677903
# std     1133.273927
# min        1.000000
# 25%       33.000000
# 50%       63.000000
# 75%      111.000000
# max    24957.000000
# CHARACTER: Penny
#           num_words
# count    387.000000
# mean     191.669251
# std     1084.098570
# min        2.000000
# 25%       32.000000
# 50%       64.000000
# 75%      128.000000
# max    16907.000000
# CHARACTER: Howard
#           num_words
# count    393.000000
# mean     165.274809
# std      607.552547
# min        1.000000
# 25%       27.000000
# 50%       62.000000
# 75%      120.000000
# max    10146.000000
# CHARACTER: Raj
#          num_words
# count   341.000000
# mean    165.140762
# std     646.951556
# min       1.000000
# 25%      22.000000
# 50%      54.000000
# 75%     104.000000
# max    9992.000000
# CHARACTER: Amy
#          num_words
# count   187.000000
# mean    199.614973
# std     789.801181
# min       1.000000
# 25%      22.500000
# 50%      61.000000
# 75%     131.500000
# max    9487.000000
# CHARACTER: Bernadette
#          num_words
# count   166.000000
# mean    155.403614
# std     384.485315
# min       1.000000
# 25%      25.250000
# 50%      55.500000
# 75%     101.750000
# max    3109.000000
# CHARACTER: Stuart
#          num_words
# count    61.000000
# mean    121.393443
# std     353.875603
# min       1.000000
# 25%      21.000000
# 50%      40.000000
# 75%      90.000000
# max    2706.000000
# CHARACTER: Mrs Cooper
#         num_words
# count   18.000000
# mean   178.055556
# std    183.996954
# min     18.000000
# 25%     78.000000
# 50%    137.000000
# 75%    174.000000
# max    783.000000
# CHARACTER: Beverley
#         num_words
# count   12.000000
# mean   159.833333
# std    177.053579
# min     10.000000
# 25%     49.000000
# 50%    130.000000
# 75%    168.000000
# max    648.000000
# CHARACTER: Priya
#         num_words
# count   29.000000
# mean    62.896552
# std     78.517216
# min      2.000000
# 25%     14.000000
# 50%     41.000000
# 75%     73.000000
# max    340.000000
# CHARACTER: Wil
#         num_words
# count   18.000000
# mean    87.611111
# std    100.251530
# min      5.000000
# 25%     23.750000
# 50%     55.000000
# 75%    134.500000
# max    405.000000
# CHARACTER: Emily
#         num_words
# count   24.000000
# mean    61.333333
# std     65.783351
# min      6.000000
# 25%     27.000000
# 50%     37.500000
# 75%     71.250000
# max    313.000000
# CHARACTER: Mrs Wolowitz
#         num_words
# count   28.000000
# mean    48.714286
# std     66.913907
# min      3.000000
# 25%      7.000000
# 50%     23.500000
# 75%     57.750000
# max    320.000000
# CHARACTER: Arthur
#         num_words
# count    9.000000
# mean   150.333333
# std    142.429807
# min     51.000000
# 25%     75.000000
# 50%    100.000000
# 75%    112.000000
# max    496.000000
# CHARACTER: Zack
#         num_words
# count   15.000000
# mean    89.066667
# std     85.758354
# min      3.000000
# 25%     30.500000
# 50%     64.000000
# 75%    122.000000
# max    325.000000
# CHARACTER: Leslie
#         num_words
# count   13.000000
# mean    89.538462
# std     70.425629
# min      3.000000
# 25%     55.000000
# 50%     64.000000
# 75%    146.000000
# max    240.000000
# CHARACTER: Kripke
#         num_words
# count   16.000000
# mean    72.687500
# std     70.293403
# min      8.000000
# 25%     34.500000
# 50%     54.000000
# 75%     67.000000
# max    265.000000
# CHARACTER: Bert
#        num_words
# count   10.00000
# mean   106.50000
# std     55.10243
# min     34.00000
# 25%     52.50000
# 50%    120.50000
# 75%    149.00000
# max    180.00000

# %% [markdown]
# The analysis from 6i) is better than the analysis in 5) because you can verify that Sheldon does generally speak more at each episode than Leonard. At each quantile shown (25, 50, 75), Sheldon's number is higher than Leonards. Thus, to improve on this analysis, we can check each scene. Above, we see that Sheldon's quantiles are still higher than Leonards, meaning that usually Sheldon talks more during each scene.

# %% [markdown]
# ### Part 3: Obligatory Spark cameo
# **Q7**. (7.5 points) Write a Spark script that does the following: Given the raw input file and your list of recurrent characters, create an RDD containing (speaker, dialogue line) rows **only for the recurrent characters** (assume that you already have the list --  no need to calculate it using Spark), and then generate a vectorized bag of words representation for each dialogue line, thus generating an RDD with (speaker, bag of words vector) rows. Then, calculate an aggregated bag of words vector (sum of all vectors) for each person. The final output is therefore an RDD with each of its rows being (speaker, aggregated bag of words vector). For your bag of words vectors, you can use $1\times|V|$ scipy CSR matrices (where $|V|$ is the size of the vocabulary). No filtering of the vocabulary is necessary for this part.
#
# You do not need to run this script, but you do need to use Spark logic and also, the syntax needs to be correct.

# %%
# TODO: Spark

# %% [markdown]
# ## Task C: The Gossip Graph (30 points)
#
# **Note: Only for this task, discard the recurrent characters whose names are not single words, e.g. Mrs. Cooper.**
#
# Let us define _gossip_ as follows: if a dialogue line of character A mentions B by name in a scene that does not involve character B, we say that “A gossips about B” in that line. Multiple mentions of the same person in a single line are counted once, but a character can gossip about several others in the same line. For the sake of simplicity, we only consider gossips where the name of the recurrent character is mentioned as it appears in our list of characters; for example, if someone says "Cooper" and they mean Sheldon, we discard that.
#
# **Q8**. (12.5 points) Create the two following graphs first:
#
# 1. (5 points) Create the _familiarity graph_, an undirected weighted graph, in which there is a node for each recurrent character, and an edge between two characters if they appear together in at least one scene. The weight of the edge between them is the number of scenes they appear in together. If an edge exists between two people in the familiarity graph, we say that they "know each other".
# 2. (7.5 points) Create the _gossip graph_, which is a directed weighted graph, in which there there is a node for each recurrent character, and a directed edge from the node for A to the node for B if A has gossiped about B at least once. The weight of the edge is the number of scenes in which A has gossiped about B.
#
# _Hint: You can create each graph first as an adjacency matrix and then create a networkx graph out of that._

# %%
import networkx as nx 

df_gos = df_diag.copy()
# get names of character's without space
df_gos = df_gos[~df_gos['character'].str.contains(' ')]

list_characters = df_gos['character'].unique()

# join names of characters in same scene
df_gos = df_gos.groupby(['episode', 'scene'])['character'].apply(lambda x: ','.join(x.unique())).reset_index()

G = nx.Graph()
G.add_nodes_from(list_characters)

for index, row in df_gos.iterrows():
    chars = row['character'].split(',')
    num_chars = len(chars)
    for i in range(num_chars - 1):
        for j in range(i, num_chars):
            char_i = chars[i]
            char_j = chars[j]
            if G.has_edge(char_i, char_j):
                G[char_i][char_j]['weight'] += 1
            else:
                G.add_edge(char_i, char_j, weight=1)

nx.draw(G, with_labels=True, font_weight='bold')

# %%
# TODO: Gossip graph
df_gos = df_diag.copy()
# get names of character's without space
df_gos = df_gos[~df_gos['character'].str.contains(' ')]

list_characters = df_gos['character'].unique()

# join names of characters in same scene & join lines
df_gos = df_gos.groupby(['episode', 'scene'])[['character', 'line']].apply(lambda x: ','.join(x['character'].unique())).reset_index()

df_gos
# Out:
#                                                 episode  \
# 0                  Series 01 Episode 01 – Pilot Episode
# 1                  Series 01 Episode 01 – Pilot Episode
# 2                  Series 01 Episode 01 – Pilot Episode
# 3                  Series 01 Episode 01 – Pilot Episode
# 4                  Series 01 Episode 01 – Pilot Episode
# 5                  Series 01 Episode 01 – Pilot Episode
# 6                  Series 01 Episode 01 – Pilot Episode
# 7                  Series 01 Episode 01 – Pilot Episode
# 8                  Series 01 Episode 01 – Pilot Episode
# 9                  Series 01 Episode 01 – Pilot Episode
# 10                 Series 01 Episode 01 – Pilot Episode
# 11                 Series 01 Episode 01 – Pilot Episode
# 12       Series 01 Episode 02 – The Big Bran Hypothesis
# 13       Series 01 Episode 02 – The Big Bran Hypothesis
# 14       Series 01 Episode 02 – The Big Bran Hypothesis
# 15       Series 01 Episode 02 – The Big Bran Hypothesis
# 16       Series 01 Episode 02 – The Big Bran Hypothesis
# 17       Series 01 Episode 02 – The Big Bran Hypothesis
# 18       Series 01 Episode 02 – The Big Bran Hypothesis
# 19       Series 01 Episode 02 – The Big Bran Hypothesis
# 20       Series 01 Episode 02 – The Big Bran Hypothesis
# 21       Series 01 Episode 02 – The Big Bran Hypothesis
# 22       Series 01 Episode 02 – The Big Bran Hypothesis
# 23     Series 01 Episode 03 – The Fuzzy Boots Corollary
# 24     Series 01 Episode 03 – The Fuzzy Boots Corollary
# 25     Series 01 Episode 03 – The Fuzzy Boots Corollary
# 26     Series 01 Episode 03 – The Fuzzy Boots Corollary
# 27     Series 01 Episode 03 – The Fuzzy Boots Corollary
# 28     Series 01 Episode 03 – The Fuzzy Boots Corollary
# 29     Series 01 Episode 03 – The Fuzzy Boots Corollary
# ...                                                 ...
# 1912    Series 10 Episode 21 – The Separation Agitation
# 1913    Series 10 Episode 21 – The Separation Agitation
# 1914   Series 10 Episode 22 – The Cognition Regenera...
# 1915   Series 10 Episode 22 – The Cognition Regenera...
# 1916   Series 10 Episode 22 – The Cognition Regenera...
# 1917   Series 10 Episode 22 – The Cognition Regenera...
# 1918   Series 10 Episode 22 – The Cognition Regenera...
# 1919   Series 10 Episode 22 – The Cognition Regenera...
# 1920   Series 10 Episode 22 – The Cognition Regenera...
# 1921   Series 10 Episode 22 – The Cognition Regenera...
# 1922   Series 10 Episode 22 – The Cognition Regenera...
# 1923   Series 10 Episode 22 – The Cognition Regenera...
# 1924     Series 10 Episode 23 – The Gyroscopic Collapse
# 1925     Series 10 Episode 23 – The Gyroscopic Collapse
# 1926     Series 10 Episode 23 – The Gyroscopic Collapse
# 1927     Series 10 Episode 23 – The Gyroscopic Collapse
# 1928     Series 10 Episode 23 – The Gyroscopic Collapse
# 1929     Series 10 Episode 23 – The Gyroscopic Collapse
# 1930     Series 10 Episode 23 – The Gyroscopic Collapse
# 1931     Series 10 Episode 23 – The Gyroscopic Collapse
# 1932     Series 10 Episode 23 – The Gyroscopic Collapse
# 1933   Series 10 Episode 24 – The Long Distance Diss...
# 1934   Series 10 Episode 24 – The Long Distance Diss...
# 1935   Series 10 Episode 24 – The Long Distance Diss...
# 1936   Series 10 Episode 24 – The Long Distance Diss...
# 1937   Series 10 Episode 24 – The Long Distance Diss...
# 1938   Series 10 Episode 24 – The Long Distance Diss...
# 1939   Series 10 Episode 24 – The Long Distance Diss...
# 1940   Series 10 Episode 24 – The Long Distance Diss...
# 1941   Series 10 Episode 24 – The Long Distance Diss...
#
#                                                   scene  \
# 0                           A corridor at a sperm bank.
# 1                            All five in Leonard’s car.
# 2                                Back at the apartment.
# 3                                      In the bathroom.
# 4               Inside Sheldon and Leonard’s apartment.
# 5             Leonard and Sheldon, Inside Leonard’s car
# 6      On the stairs of Sheldon and Leonard’s building.
# 7             Outside Penny’s ex-boyfriend’s apartment.
# 8               Outside Penny’s old apartment building.
# 9      Outside the apartment building. Leonard and S...
# 10                     Sheldon and Leonard’s apartment.
# 11                The stairs of the apartment building.
# 12     Ground floor hallway of the apartment buildin...
# 13     Inside Penny’s apartment. They are laying the...
# 14     Leonard’s bedroom, he is asleep. Sound of doo...
# 15     Penny’s apartment, penny is sleeping, Sheldon...
# 16     Penny’s apartment. Sheldon and Leonard are tr...
# 17     Sheldon and Leonard’s apartment. Sheldon, Leo...
# 18     Sheldon and Leonard’s living room, morning. S...
# 19     Sheldon and Leonard’s living room. Howard is ...
# 20     The hallway, Leonard puts a note under Penny’...
# 21     The living room. Leonard enters carrying a li...
# 22     The stairwell. Raj is coming up the stairs, h...
# 23                                        A restaurant.
# 24     A salsa class. The four guys and a random fat...
# 25                             Howard and Lesley’s lab.
# 26     Sheldon and Leonard’s apartment. Leonard ente...
# 27     Sheldon and Leonard’s apartment. Sheldon, Leo...
# 28     Sheldon and Leonard’s flat. Sheldon, Raj and ...
# 29                       The apartment, Leonard enters.
# ...                                                 ...
# 1912                                     The cafeteria.
# 1913                                       The daycare.
# 1914                                             A bar.
# 1915                                      A restaurant.
# 1916                                          A street.
# 1917                   Howard and Bernadette’s kitchen.
# 1918                                       Penny’s car.
# 1919                       Sheldon and Amy’s apartment.
# 1920                         Sheldon and Amy’s bedroom.
# 1921                                     The apartment.
# 1922                              The comic book store.
# 1923                                    The restaurant.
# 1924                                            A park.
# 1925                  Howard and Bernadette’s bathroom.
# 1926                       Howard and Bernadette’s van.
# 1927                                   Outside the lab.
# 1928                       Sheldon and Amy’s apartment.
# 1929                             The apartment doorway.
# 1930                                     The apartment.
# 1931                                   The laboratory .
# 1932                                     The stairwell.
# 1933                                         Princeton.
# 1934                          Sheldon and Amy on skype.
# 1935                       Sheldon and Amy’s apartment.
# 1936                                  Sheldon’s office.
# 1937                                     The apartment.
# 1938                                     The cafeteria.
# 1939                              The comic book store.
# 1940                                   The same, later.
# 1941                                        The street.
#
#                                                     0
# 0                                     Sheldon,Leonard
# 1                        Leonard,Penny,Sheldon,Howard
# 2                                        Penny,Howard
# 3                                       Leonard,Penny
# 4                    Howard,Penny,Raj,Leonard,Sheldon
# 5                                     Sheldon,Leonard
# 6                                     Leonard,Sheldon
# 7                                     Leonard,Sheldon
# 8                                     Leonard,Sheldon
# 9                                     Sheldon,Leonard
# 10                   Leonard,Penny,Sheldon,Howard,Raj
# 11                              Sheldon,Leonard,Penny
# 12                                    Leonard,Sheldon
# 13                              Sheldon,Leonard,Penny
# 14                                            Leonard
# 15                                    Leonard,Sheldon
# 16                       Leonard,Sheldon,Penny,Howard
# 17                   Leonard,Howard,Sheldon,Raj,Penny
# 18                              Sheldon,Leonard,Penny
# 19                         Howard,Leonard,Sheldon,Raj
# 20                                      Penny,Leonard
# 21                                            Leonard
# 22                                          Penny,Raj
# 23                                      Penny,Leonard
# 24                                             Howard
# 25                                            Leonard
# 26                                    Leonard,Sheldon
# 27                         Howard,Sheldon,Raj,Leonard
# 28                         Howard,Sheldon,Raj,Leonard
# 29                                    Sheldon,Leonard
# ...                                               ...
# 1912                         Sheldon,Raj,Leonard,Bert
# 1913                         Bernadette,Howard,Stuart
# 1914                        Penny,Bernadette,Amy,Zack
# 1915                                       Zack,Penny
# 1916                                          Sheldon
# 1917                  Howard,Sheldon,Bernadette,Penny
# 1918                                    Penny,Leonard
# 1919                                  Amy,Sheldon,Raj
# 1920                                      Amy,Sheldon
# 1921            Leonard,Howard,Raj,Sheldon,Penny,Zack
# 1922                       Sheldon,Leonard,Raj,Howard
# 1923                               Zack,Leonard,Penny
# 1924                      Bernadette,Amy,Penny,Howard
# 1925                                Howard,Bernadette
# 1926                                Bernadette,Howard
# 1927                           Leonard,Howard,Sheldon
# 1928                                      Amy,Sheldon
# 1929                    Raj,Leonard,Penny,Sheldon,Amy
# 1930  Penny,Leonard,Sheldon,Amy,Bernadette,Raj,Howard
# 1931                           Leonard,Howard,Sheldon
# 1932                       Howard,Leonard,Sheldon,Raj
# 1933                                          Sheldon
# 1934                                      Sheldon,Amy
# 1935                                Sheldon,Amy,Penny
# 1936                                          Sheldon
# 1937  Penny,Bernadette,Amy,Leonard,Raj,Sheldon,Howard
# 1938                       Howard,Leonard,Raj,Sheldon
# 1939                        Howard,Leonard,Raj,Stuart
# 1940             Leonard,Sheldon,Bernadette,Penny,Raj
# 1941                                    Sheldon,Penny
#
# [1942 rows x 3 columns]

# %% [markdown]
# Now, answer the following questions:
#
# **Q9**. (5 points) Sheldon claims that every character in the show is familiar with everyone else through at most one intermediary. Based on the familiarity graph, is this true? If not, at most how many intermediaries are needed?

# %% [markdown]
# Based on the graph, this appears to be true. This is because the main characters of the show (aka the cluster in the middle of the graph) which include Howard, Bernadette, Amy, Sheldon, Penny, Leonard, and Raj are all connected to the secondary characters.

# %% [markdown]
# **Q10**. (5 points) Who is the character through whom the largest number of these indirect familiarities happen? Calculate an appropriate centrality metric on the familiarity graph to answer this question. You can use the package networkx for this section.

# %%
nx.algorithms.centrality.degree_centrality(G)
# Out:
# {'Sheldon': 1.125,
#  'Leonard': 1.125,
#  'Penny': 1.125,
#  'Howard': 1.125,
#  'Raj': 1.125,
#  'Leslie': 0.75,
#  'Kripke': 0.625,
#  'Beverley': 0.75,
#  'Stuart': 1.0,
#  'Bernadette': 0.9375,
#  'Wil': 0.875,
#  'Zack': 0.625,
#  'Amy': 1.125,
#  'Priya': 0.5625,
#  'Arthur': 0.5,
#  'Bert': 0.5625,
#  'Emily': 0.6875}

# %% [markdown]
# According the the degree centrality of G, the character whom the largest number of these indirect familiarities happen is Arthur w/a value of 0.5.

# %% [markdown]
# **Q11**. (2.5 points) Another claim of Sheldon's is that every recurrent character in the show gossips about all the other recurrent characters. What property of the gossip graph would correspond to this? Does the gossip graph possess that property? If not, then is it the case that for every pair of recurrent characters, at least one gossips about the other? What property would this correspond to?

# %% [markdown]
# **Q12**. (5 points) Use the gossip graph and the familiarity graph to figure out if for every pair of recurrent characters, one of them has gossiped about the other if and only if they know each other. Explain your method - the simpler, the better.

# %% [markdown]
# ## Task D: The Detective's Hat (30 points)
#
# Sheldon claims that given a dialogue line, he can, with an accuracy of above 70%, say whether it's by himself or by someone else. Leonard contests this claim, since he believes that this claimed accuracy is too high. Leonard also suspects that it's easier for Sheldon to distinguish the lines that _aren't_ his, rather than those that _are_. We want you to put on the (proverbial) detective's hat and to investigate this claim.
#
# **Q13**. (7.5 points) Divide the set of all dialogue lines into two subsets: the training set, consisting of all the seasons except the last two, and the test set, consisting of the last two seasons. Each of your data points (which is one row of your matrix) is one **dialogue line**. Now, use the scikit-learn class **TfIdfVectorizer** to create TF-IDF representations for the data points in your training and test sets. Note that since you're going to train a machine learning model, everything used in the training needs to be independent of the test set. As a preprocessing step, remove stopwords and words that appear only once from your vocabulary. Use the simple tokenizer provided in `helpers/helper_functions.py` as an input to the TfidfVectorizer class, and use the words provided in `helpers/stopwords.txt` as your stopwords.

# %%
training_set = df_diag[~((df_diag['episode'].str.contains('Series 10')) 
                         | (df_diag['episode'].str.contains('Series 09')))]
testing_set = df_diag[((df_diag['episode'].str.contains('Series 10')) 
                         | (df_diag['episode'].str.contains('Series 09')))]
# Out:
#                                                  episode  \
# 0                   Series 01 Episode 01 – Pilot Episode
# 1                   Series 01 Episode 01 – Pilot Episode
# 2                   Series 01 Episode 01 – Pilot Episode
# 3                   Series 01 Episode 01 – Pilot Episode
# 5                   Series 01 Episode 01 – Pilot Episode
# 7                   Series 01 Episode 01 – Pilot Episode
# 9                   Series 01 Episode 01 – Pilot Episode
# 11                  Series 01 Episode 01 – Pilot Episode
# 13                  Series 01 Episode 01 – Pilot Episode
# 14                  Series 01 Episode 01 – Pilot Episode
# 15                  Series 01 Episode 01 – Pilot Episode
# 16                  Series 01 Episode 01 – Pilot Episode
# 17                  Series 01 Episode 01 – Pilot Episode
# 18                  Series 01 Episode 01 – Pilot Episode
# 19                  Series 01 Episode 01 – Pilot Episode
# 20                  Series 01 Episode 01 – Pilot Episode
# 21                  Series 01 Episode 01 – Pilot Episode
# 22                  Series 01 Episode 01 – Pilot Episode
# 23                  Series 01 Episode 01 – Pilot Episode
# 24                  Series 01 Episode 01 – Pilot Episode
# 25                  Series 01 Episode 01 – Pilot Episode
# 26                  Series 01 Episode 01 – Pilot Episode
# 28                  Series 01 Episode 01 – Pilot Episode
# 29                  Series 01 Episode 01 – Pilot Episode
# 30                  Series 01 Episode 01 – Pilot Episode
# 31                  Series 01 Episode 01 – Pilot Episode
# 32                  Series 01 Episode 01 – Pilot Episode
# 33                  Series 01 Episode 01 – Pilot Episode
# 34                  Series 01 Episode 01 – Pilot Episode
# 35                  Series 01 Episode 01 – Pilot Episode
# ...                                                  ...
# 40324   Series 08 Episode 24 – The Commitment Determi...
# 40325   Series 08 Episode 24 – The Commitment Determi...
# 40326   Series 08 Episode 24 – The Commitment Determi...
# 40327   Series 08 Episode 24 – The Commitment Determi...
# 40328   Series 08 Episode 24 – The Commitment Determi...
# 40329   Series 08 Episode 24 – The Commitment Determi...
# 40330   Series 08 Episode 24 – The Commitment Determi...
# 40331   Series 08 Episode 24 – The Commitment Determi...
# 40332   Series 08 Episode 24 – The Commitment Determi...
# 40333   Series 08 Episode 24 – The Commitment Determi...
# 40334   Series 08 Episode 24 – The Commitment Determi...
# 40335   Series 08 Episode 24 – The Commitment Determi...
# 40336   Series 08 Episode 24 – The Commitment Determi...
# 40337   Series 08 Episode 24 – The Commitment Determi...
# 40338   Series 08 Episode 24 – The Commitment Determi...
# 40339   Series 08 Episode 24 – The Commitment Determi...
# 40340   Series 08 Episode 24 – The Commitment Determi...
# 40341   Series 08 Episode 24 – The Commitment Determi...
# 40342   Series 08 Episode 24 – The Commitment Determi...
# 40343   Series 08 Episode 24 – The Commitment Determi...
# 40344   Series 08 Episode 24 – The Commitment Determi...
# 40345   Series 08 Episode 24 – The Commitment Determi...
# 40346   Series 08 Episode 24 – The Commitment Determi...
# 40347   Series 08 Episode 24 – The Commitment Determi...
# 40348   Series 08 Episode 24 – The Commitment Determi...
# 40349   Series 08 Episode 24 – The Commitment Determi...
# 40350   Series 08 Episode 24 – The Commitment Determi...
# 40351   Series 08 Episode 24 – The Commitment Determi...
# 40352   Series 08 Episode 24 – The Commitment Determi...
# 40353   Series 08 Episode 24 – The Commitment Determi...
#
#                                         scene character  \
# 0                 A corridor at a sperm bank.   Sheldon
# 1                 A corridor at a sperm bank.   Leonard
# 2                 A corridor at a sperm bank.   Sheldon
# 3                 A corridor at a sperm bank.   Leonard
# 5                 A corridor at a sperm bank.   Leonard
# 7                 A corridor at a sperm bank.   Leonard
# 9                 A corridor at a sperm bank.   Sheldon
# 11                A corridor at a sperm bank.   Leonard
# 13                A corridor at a sperm bank.   Sheldon
# 14                A corridor at a sperm bank.   Leonard
# 15                A corridor at a sperm bank.   Sheldon
# 16                A corridor at a sperm bank.   Leonard
# 17                A corridor at a sperm bank.   Sheldon
# 18                A corridor at a sperm bank.   Leonard
# 19                A corridor at a sperm bank.   Sheldon
# 20                A corridor at a sperm bank.   Leonard
# 21                A corridor at a sperm bank.   Sheldon
# 22                A corridor at a sperm bank.   Leonard
# 23                A corridor at a sperm bank.   Sheldon
# 24                A corridor at a sperm bank.   Leonard
# 25                A corridor at a sperm bank.   Sheldon
# 26                A corridor at a sperm bank.   Leonard
# 28                A corridor at a sperm bank.   Sheldon
# 29                A corridor at a sperm bank.   Leonard
# 30      The stairs of the apartment building.   Sheldon
# 31      The stairs of the apartment building.   Leonard
# 32      The stairs of the apartment building.   Sheldon
# 33      The stairs of the apartment building.   Leonard
# 34      The stairs of the apartment building.   Sheldon
# 35      The stairs of the apartment building.   Leonard
# ...                                       ...       ...
# 40324                          Leonard’s car.   Leonard
# 40325                          Leonard’s car.     Penny
# 40326                          Leonard’s car.   Leonard
# 40327                          Leonard’s car.     Penny
# 40328                          Leonard’s car.   Leonard
# 40329                          Leonard’s car.     Penny
# 40330                          Leonard’s car.   Leonard
# 40331                          Leonard’s car.     Penny
# 40332                          Leonard’s car.   Leonard
# 40333                          Leonard’s car.     Penny
# 40334                          Leonard’s car.   Leonard
# 40335                          Leonard’s car.     Penny
# 40336                          Leonard’s car.   Leonard
# 40337                          Leonard’s car.     Penny
# 40338                          Leonard’s car.   Leonard
# 40339                          Leonard’s car.     Penny
# 40340                          Leonard’s car.   Leonard
# 40341                          Leonard’s car.     Penny
# 40342                          Leonard’s car.   Leonard
# 40343                          Leonard’s car.     Penny
# 40344                          The apartment.       Amy
# 40345                          The apartment.   Sheldon
# 40346                          The apartment.       Amy
# 40347                          The apartment.   Sheldon
# 40348                          The apartment.       Amy
# 40349                          The apartment.   Sheldon
# 40350                          The apartment.       Amy
# 40351                          The apartment.   Sheldon
# 40352                          The apartment.       Amy
# 40353                          The apartment.   Sheldon
#
#                                                     line
# 0       so if a photon is directed through a plane wi...
# 1                             agreed, what’s your point?
# 2       there’s no point, i just think it’s a good id...
# 3                                             excuse me?
# 5       one across is aegean, eight down is nabakov, ...
# 7               yes. um, is this the high iq sperm bank?
# 9                             i think this is the place.
# 11                       thank-you. we’ll be right back.
# 13                 leonard, i don’t think i can do this.
# 14             what, are you kidding? you’re a semi-pro.
# 15      no. we are committing genetic fraud. there’s ...
# 16      sheldon, this was your idea. a little extra m...
# 17      i know, and i do yearn for faster downloads, ...
# 18                       i’m sure she’ll still love him.
# 19                                           i wouldn’t.
# 20                         well, what do you want to do?
# 21                                      i want to leave.
# 22                                                 okay.
# 23                      what’s the protocol for leaving?
# 24      i don’t know, i’ve never reneged on a proffer...
# 25                           let’s try just walking out.
# 26                                                 okay.
# 28                                               bye-bye
# 29                                              see you.
# 30               are you still mad about the sperm bank?
# 31                                                   no.
# 32      you want to hear an interesting thing about s...
# 33                                           not really.
# 34      if the height of a single step is off by as l...
# 35      i don’t care. two millimetres? that doesn’t s...
# ...                                                  ...
# 40324   well, like i said, we’re about to get married...
# 40325   really? because to me, it seems like we’re ab...
# 40326                would you rather i didn’t tell you?
# 40327   no, i don’t want there to be secrets between us.
# 40328   see, now i’m confused. i mean, what, what am ...
# 40329               uh, keep your mouth off other women.
# 40330   i can do that. uh, uh, from now on, this mout...
# 40331                                              okay.
# 40332                                              yeah?
# 40333   look, i’m not happy this happened, but i thin...
# 40334                                             right.
# 40335                                      just kissing.
# 40336   it wasn’t even very good. she was a smoker, i...
# 40337                 okay, that’s enough. stop talking.
# 40338                   so, we’re still getting married?
# 40339                                               yes.
# 40340                        because we love each other.
# 40341                                               yes.
# 40342            and it’s the happiest day of our lives.
# 40343                              ha-ha, don’t push it.
# 40344                                             hello.
# 40345   hello. listen, i’ve been thinking a lot about...
# 40346   i’ve been thinking about them, too, sheldon. ...
# 40347                          strongly disagree. go on.
# 40348   okay, well, this isn’t easy to say, because i...
# 40349                                                oh.
# 40350                             i hope you understand.
# 40351                                              okay.
# 40352                                      bye, sheldon.
# 40353   well, gollum, you’re an expert on rings. what...
#
# [38177 rows x 4 columns]

# %% [markdown]
# **Q14**. (5 points) Find the set of all words in the training set that are only uttered by Sheldon. Is it possible for Sheldon to identify himself only based on these? Use the test set to assess this possibility, and explain your method.

# %% [markdown]
# **Q15**. (17.5 points) Now, perform singular value decomposition (SVD) on the training TF-IDF matrix, and calculate a **25-dimensional approximation** for both the training and test TF-IDF matrices (you can do this using scikit-learn's **TruncatedSVD** class). Then, train a logistic regression classifier with 10-fold cross-validation (using the scikit-learn **LogisticRegressionCV** class) on the output of the SVD that given a dialogue line, tells you whether it's by Sheldon or by someone else.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**i)** (7.5 points) Report precision, recall and F1-score for both classes (Sheldon and not-Sheldon), as well as accuracy, of your classifier on the training set and the test set. You need to implement the calculation of the evaluation measures (precision, etc.) yourself -- using the scikit-learn functions for them is not allowed.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**ii)** (5 points) What difference do you observe between the model's scores on the training and test sets? What could you infer from the amount of difference you see? What about the difference between scores on the two classes? Given the performance of your classifier, is Leonard right that the accuracy Sheldon claims is unattainable? What about his suspicions about the lines that Sheldon can and cannot distinguish?
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**iii)** (2.5 points) List 10 of the most extreme false positives and 10 of the most extreme false negatives, in terms of the probabilities predicted by the logistic regression model. What are common features of false positives? What about the false negatives?
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**iv)** (2.5 points) What is the most important feature in the model? What are the 5 most important words in this feature? _Hint: Think of the definition of an SVD, and that you did an SVD on the TF-IDF matrix with dialogue lines as rows and words as columns. You have projected the original data points onto a 25-dimensional subspace -- you need to look at the unit vectors you used for the projection._
